# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Dict
from utils import *
import seaborn as sns
from typing import Iterable
output = ""

# %%
GROWTH_YEAR_MIN, GROWTH_YEAR_MAX = 2012, 2023

stats = compute_ceg_statistics(GROWTH_YEAR_MIN, GROWTH_YEAR_MAX)


output += f"{stats['total_cumulative_growth']:>12.2f}x  Final cumulative multiplier (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{22000 / stats['total_cumulative_growth']:>12.2f}x  Gap from Ho et al. (from {stats['growth_year_min']} to {stats['growth_year_max']})\n" 
output += f"{(np.log(stats['scale_dependent_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from scale-dependent (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['total_transformer_growth']:>12.2f}x  Total multiplier from from transformer (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(np.log(stats['total_transformer_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from from transformer (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['total_chinchilla_growth']:>12.2f}x  Total multiplier from from Chinchilla (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(np.log(stats['total_chinchilla_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from from Chinchilla (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['scale_dependent_growth']:>12.2f}x  Scale-dependent multiplier (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(np.log(stats['scale_invariant_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from scale-invariant (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['scale_invariant_growth']:>12.2f}x  Scale-invariant multiplier (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(stats['total_cumulative_growth'] / stats['initial_cumulative_growth']) ** (1/(stats['growth_year_max']-stats['growth_year_min'])):>12.4f}x  Rate of growth (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"               Compute range for analysis: {ytc(GROWTH_YEAR_MIN):.3g}, {ytc(GROWTH_YEAR_MAX):.3g}\n"
output += f"{2**(12/8):>12.2f}x  Ho et al annual growth rate (from {2012} to {2023})\n"

output += "\n"

# %%
GROWTH_YEAR_MIN, GROWTH_YEAR_MAX = 2013, 2025

stats = compute_ceg_statistics(GROWTH_YEAR_MIN, GROWTH_YEAR_MAX)

output += f"{stats['total_cumulative_growth']:>12.2f}x  Final cumulative multiplier (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{22000 / stats['total_cumulative_growth']:>12.2f}x  Gap from Ho et al. (from {stats['growth_year_min']} to {stats['growth_year_max']})\n" 
output += f"{(np.log(stats['scale_dependent_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from scale-dependent (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['total_transformer_growth']:>12.2f}x  Total multiplier from from transformer (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(np.log(stats['total_transformer_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from from transformer (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['total_chinchilla_growth']:>12.2f}x  Total multiplier from from Chinchilla (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(np.log(stats['total_chinchilla_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from from Chinchilla (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['scale_dependent_growth']:>12.2f}x  Scale-dependent multiplier (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(np.log(stats['scale_invariant_growth'])/np.log(stats['total_cumulative_growth']) * 100):>12.2f}%  Proportion from scale-invariant (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{stats['scale_invariant_growth']:>12.2f}x  Scale-invariant multiplier (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"{(stats['total_cumulative_growth'] / stats['initial_cumulative_growth']) ** (1/(stats['growth_year_max']-stats['growth_year_min'])):>12.4f}x  Rate of growth (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"
output += f"               Compute range for analysis: {ytc(GROWTH_YEAR_MIN):.3g}, {ytc(GROWTH_YEAR_MAX):.3g}\n"

# %%
GROWTH_YEAR_MIN, GROWTH_YEAR_MAX = 2013, 2017.01

stats = compute_ceg_statistics(GROWTH_YEAR_MIN, GROWTH_YEAR_MAX)

output += f"{stats['total_transformer_growth']:>12.2f}x  Total transformer growth (from {stats['growth_year_min']} to {stats['growth_year_max']})\n"

# %%
print(output)

# %%
# something for scale of improvements for only our own algs
# each individual alg?

# %%
with open("numbers.txt", "w") as f:
    f.write(output)
