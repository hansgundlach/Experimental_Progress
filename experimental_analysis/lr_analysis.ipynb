# %% [markdown]
# # No Bias

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Data
model_width = np.array([32, 64, 160, 256])
optimal_lr = np.array([10**-2, 10**-2.25, 10**-2.5, 10**-2.75])

# Fit function: assume a power law for lr = A * width ^ B
def power_law(width, A, B):
    return A * width ** B

# Fit in log space for more stability
popt, pcov = curve_fit(power_law, model_width, optimal_lr, p0=[1e-3, 0])

# Extrapolate to width=hidden_dims, print each
hidden_dims = [32, 48,  64, 80, 96, 104, 128, 160,192, 224, 256]
extrapolated_lrs = [power_law(w, *popt) for w in hidden_dims]
for w, lr in zip(hidden_dims, extrapolated_lrs):
    print(f"Extrapolated optimal LR for width={w}: {lr:.4e}")

print(f"Fit parameters: A={popt[0]:.4e}, B={popt[1]:.4f}")

# For plotting, highlight one width (e.g., last in hidden_dims)
highlight_idx = -1  # pick last one
highlight_dim = hidden_dims[highlight_idx]
highlight_lr = extrapolated_lrs[highlight_idx]
print(f"Extrapolated optimal LR for width={highlight_dim}: {highlight_lr:.4e}")

# Plot
plt.figure(figsize=(8,6))
plt.scatter(model_width, optimal_lr, label='Data', color='blue')
widths_for_line = np.linspace(min(model_width), 512, 200)
plt.plot(widths_for_line, power_law(widths_for_line, *popt), 'r--', label='Power Law Fit')
plt.scatter([highlight_dim], [highlight_lr], color='green', marker='x', label=f'Extrapolated (w={highlight_dim})')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Model Width')
plt.ylabel('Optimal LR')
plt.title('Model Width vs. Optimal LR No Bias (Log Scale)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Extrapolated optimal LR for width=32: 9.9529e-03
# Extrapolated optimal LR for width=48: 7.2559e-03
# Extrapolated optimal LR for width=64: 5.7983e-03
# Extrapolated optimal LR for width=80: 4.8726e-03
# Extrapolated optimal LR for width=96: 4.2271e-03
# Extrapolated optimal LR for width=104: 3.9714e-03
# Extrapolated optimal LR for width=128: 3.3779e-03
# Extrapolated optimal LR for width=160: 2.8386e-03
# Extrapolated optimal LR for width=192: 2.4626e-03
# Extrapolated optimal LR for width=224: 2.1837e-03
# Extrapolated optimal LR for width=256: 1.9679e-03
# Fit parameters: A=1.4832e-01, B=-0.7795
# Extrapolated optimal LR for width=256: 1.9679e-03

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Data
model_width = np.array([32, 64, 160, 256])
optimal_lr = np.array([10**-2, 10**-2.25, 10**-2.5, 10**-2.75])

# Fit function: assume a power law for lr = A * width ^ B
def power_law(width, A, B):
    return A * width ** B

# Fit in log space for more stability
popt, pcov = curve_fit(power_law, model_width, optimal_lr, p0=[1e-3, 0])

# Extrapolate to width=hidden_dims, print each
hidden_dims = [32, 48,  64, 80, 96, 104, 128, 160,192, 224, 256]
extrapolated_lrs = [power_law(w, *popt) for w in hidden_dims]
for w, lr in zip(hidden_dims, extrapolated_lrs):
    print(f"Extrapolated optimal LR for width={w}: {lr:.4e}")

print(f"Fit parameters: A={popt[0]:.4e}, B={popt[1]:.4f}")

# For plotting, highlight one width (e.g., last in hidden_dims)
highlight_idx = -1  # pick last one
highlight_dim = hidden_dims[highlight_idx]
highlight_lr = extrapolated_lrs[highlight_idx]
print(f"Extrapolated optimal LR for width={highlight_dim}: {highlight_lr:.4e}")

# Plot
plt.figure(figsize=(8,6))
plt.scatter(model_width, optimal_lr, label='Data', color='blue')
widths_for_line = np.linspace(min(model_width), 512, 200)
plt.plot(widths_for_line, power_law(widths_for_line, *popt), 'r--', label='Power Law Fit')
plt.scatter([highlight_dim], [highlight_lr], color='green', marker='x', label=f'Extrapolated (w={highlight_dim})')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Model Width')
plt.ylabel('Optimal LR')
plt.title('Model Width vs. Optimal LR Current (Log Scale)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Extrapolated optimal LR for width=32: 9.9529e-03
# Extrapolated optimal LR for width=48: 7.2559e-03
# Extrapolated optimal LR for width=64: 5.7983e-03
# Extrapolated optimal LR for width=80: 4.8726e-03
# Extrapolated optimal LR for width=96: 4.2271e-03
# Extrapolated optimal LR for width=104: 3.9714e-03
# Extrapolated optimal LR for width=128: 3.3779e-03
# Extrapolated optimal LR for width=160: 2.8386e-03
# Extrapolated optimal LR for width=192: 2.4626e-03
# Extrapolated optimal LR for width=224: 2.1837e-03
# Extrapolated optimal LR for width=256: 1.9679e-03
# Fit parameters: A=1.4832e-01, B=-0.7795
# Extrapolated optimal LR for width=256: 1.9679e-03

# %% [markdown]
# # LR Analysis Historical

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Data
model_width = np.array([32, 64, 96, 160])
optimal_lr = np.array([10**-2.25, 10**-2.75, 10**-3, 10**-3.25])

# Fit function: assume a power law for lr = A * width ^ B
def power_law(width, A, B):
    return A * width ** B

# Fit in log space for more stability
popt, pcov = curve_fit(power_law, model_width, optimal_lr, p0=[1e-3, 0])

# Extrapolate to width=hidden_dims, print each
hidden_dims = [32, 48,  64, 80, 96, 104, 128, 160,192,224,256]
extrapolated_lrs = [power_law(w, *popt) for w in hidden_dims]
for w, lr in zip(hidden_dims, extrapolated_lrs):
    print(f"Extrapolated optimal LR for width={w}: {lr:.4e}")

print(f"Fit parameters: A={popt[0]:.4e}, B={popt[1]:.4f}")

# For plotting, highlight one width (e.g., last in hidden_dims)
highlight_idx = -1  # pick last one
highlight_dim = hidden_dims[highlight_idx]
highlight_lr = extrapolated_lrs[highlight_idx]
print(f"Extrapolated optimal LR for width={highlight_dim}: {highlight_lr:.4e}")

# Plot
plt.figure(figsize=(8,6))
plt.scatter(model_width, optimal_lr, label='Data', color='blue')
widths_for_line = np.linspace(min(model_width), 512, 200)
plt.plot(widths_for_line, power_law(widths_for_line, *popt), 'r--', label='Power Law Fit')
plt.scatter([highlight_dim], [highlight_lr], color='green', marker='x', label=f'Extrapolated (w={highlight_dim})')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Model Width')
plt.ylabel('Optimal LR')
plt.title('Model Width vs. Optimal LR Historical(Log Scale)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Extrapolated optimal LR for width=32: 5.6082e-03
# Extrapolated optimal LR for width=48: 2.9450e-03
# Extrapolated optimal LR for width=64: 1.8646e-03
# Extrapolated optimal LR for width=80: 1.3081e-03
# Extrapolated optimal LR for width=96: 9.7915e-04
# Extrapolated optimal LR for width=104: 8.6223e-04
# Extrapolated optimal LR for width=128: 6.1996e-04
# Extrapolated optimal LR for width=160: 4.3492e-04
# Extrapolated optimal LR for width=192: 3.2555e-04
# Extrapolated optimal LR for width=224: 2.5484e-04
# Extrapolated optimal LR for width=256: 2.0613e-04
# Fit parameters: A=1.3803e+00, B=-1.5886
# Extrapolated optimal LR for width=256: 2.0613e-04

# %% [markdown]
# # HISTORICAL LR STUDY (SINUSOIDAL)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Data
model_width = np.array([32, 64, 96, 160])
optimal_lr = np.array([10**-2.5, 10**-2.75, 10**-3, 10**-3.25])

# Fit function: assume a power law for lr = A * width ^ B
def power_law(width, A, B):
    return A * width ** B

# Fit in log space for more stability
popt, pcov = curve_fit(power_law, model_width, optimal_lr, p0=[1e-3, 0])

# Extrapolate to width=hidden_dims, print each
hidden_dims = [32, 48,  64, 80, 96, 104, 128, 160,192,224,256]
extrapolated_lrs = [power_law(w, *popt) for w in hidden_dims]
for w, lr in zip(hidden_dims, extrapolated_lrs):
    print(f"Extrapolated optimal LR for width={w}: {lr:.4e}")

print(f"Fit parameters: A={popt[0]:.4e}, B={popt[1]:.4f}")

# For plotting, highlight one width (e.g., last in hidden_dims)
highlight_idx = -1  # pick last one
highlight_dim = hidden_dims[highlight_idx]
highlight_lr = extrapolated_lrs[highlight_idx]
print(f"Extrapolated optimal LR for width={highlight_dim}: {highlight_lr:.4e}")

# Plot
plt.figure(figsize=(8,6))
plt.scatter(model_width, optimal_lr, label='Data', color='blue')
widths_for_line = np.linspace(min(model_width), 512, 200)
plt.plot(widths_for_line, power_law(widths_for_line, *popt), 'r--', label='Power Law Fit')
plt.scatter([highlight_dim], [highlight_lr], color='green', marker='x', label=f'Extrapolated (w={highlight_dim})')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Model Width')
plt.ylabel('Optimal LR')
plt.title('Model Width vs. Optimal LR Historical(Log Scale)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Extrapolated optimal LR for width=32: 3.2015e-03
# Extrapolated optimal LR for width=48: 2.1430e-03
# Extrapolated optimal LR for width=64: 1.6118e-03
# Extrapolated optimal LR for width=80: 1.2923e-03
# Extrapolated optimal LR for width=96: 1.0789e-03
# Extrapolated optimal LR for width=104: 9.9669e-04
# Extrapolated optimal LR for width=128: 8.1149e-04
# Extrapolated optimal LR for width=160: 6.5063e-04
# Extrapolated optimal LR for width=192: 5.4317e-04
# Extrapolated optimal LR for width=224: 4.6629e-04
# Extrapolated optimal LR for width=256: 4.0855e-04
# Fit parameters: A=9.8982e-02, B=-0.9901
# Extrapolated optimal LR for width=256: 4.0855e-04

# %% [markdown]
# # LSTM LR SCALING

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Data
model_width = np.array([64, 128, 256])
optimal_lr = np.array([10**-1.5, 10**-1.75,10**-2])

# Fit function: assume a power law for lr = A * width ^ B
def power_law(width, A, B):
    return A * width ** B

# Fit in log space for more stability
popt, pcov = curve_fit(power_law, model_width, optimal_lr, p0=[1e-3, 0])

# Extrapolate to width=hidden_dims, print each
hidden_dims = [32, 48,  64, 80, 96, 104, 128, 160, 192, 224, 256, 320, 384, 448, 512]
extrapolated_lrs = [power_law(w, *popt) for w in hidden_dims]
for w, lr in zip(hidden_dims, extrapolated_lrs):
    print(f"Extrapolated optimal LR for width={w}: {lr:.4e}")

print(f"Fit parameters: A={popt[0]:.4e}, B={popt[1]:.4f}")

# For plotting, highlight one width (e.g., last in hidden_dims)
highlight_idx = -1  # pick last one
highlight_dim = hidden_dims[highlight_idx]
highlight_lr = extrapolated_lrs[highlight_idx]
print(f"Extrapolated optimal LR for width={highlight_dim}: {highlight_lr:.4e}")

# Plot
plt.figure(figsize=(8,6))
plt.scatter(model_width, optimal_lr, label='Data', color='blue')
widths_for_line = np.linspace(min(model_width), 512, 200)
plt.plot(widths_for_line, power_law(widths_for_line, *popt), 'r--', label='Power Law Fit')
plt.scatter([highlight_dim], [highlight_lr], color='green', marker='x', label=f'Extrapolated (w={highlight_dim})')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Model Width')
plt.ylabel('Optimal LR')
plt.title('Model Width vs. Optimal LR (Log Scale)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Extrapolated optimal LR for width=32: 5.6234e-02
# Extrapolated optimal LR for width=48: 4.0157e-02
# Extrapolated optimal LR for width=64: 3.1623e-02
# Extrapolated optimal LR for width=80: 2.6274e-02
# Extrapolated optimal LR for width=96: 2.2582e-02
# Extrapolated optimal LR for width=104: 2.1130e-02
# Extrapolated optimal LR for width=128: 1.7783e-02
# Extrapolated optimal LR for width=160: 1.4775e-02
# Extrapolated optimal LR for width=192: 1.2699e-02
# Extrapolated optimal LR for width=224: 1.1173e-02
# Extrapolated optimal LR for width=256: 1.0000e-02
# Extrapolated optimal LR for width=320: 8.3084e-03
# Extrapolated optimal LR for width=384: 7.1410e-03
# Extrapolated optimal LR for width=448: 6.2829e-03
# Extrapolated optimal LR for width=512: 5.6234e-03
# Fit parameters: A=1.0000e+00, B=-0.8305
# Extrapolated optimal LR for width=512: 5.6234e-03

# %% [markdown]
# # SGD Scaling

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Data
model_width = np.array([32, 64, 128, 256])
optimal_lr = np.array([10**-1, 10**-.75, 10**-0.5, 10**-.25])

# Fit function: assume a power law for lr = A * width ^ B
def power_law(width, A, B):
    return A * width ** B

# Fit in log space for more stability
popt, pcov = curve_fit(power_law, model_width, optimal_lr, p0=[1e-3, 0])

# Extrapolate to width=hidden_dims, print each
hidden_dims = [32, 48,  64, 80, 96, 104, 128, 160, 192, 224,256]
extrapolated_lrs = [power_law(w, *popt) for w in hidden_dims]
for w, lr in zip(hidden_dims, extrapolated_lrs):
    print(f"Extrapolated optimal LR for width={w}: {lr:.4e}")

print(f"Fit parameters: A={popt[0]:.4e}, B={popt[1]:.4f}")

# For plotting, highlight one width (e.g., last in hidden_dims)
highlight_idx = -1  # pick last one
highlight_dim = hidden_dims[highlight_idx]
highlight_lr = extrapolated_lrs[highlight_idx]
print(f"Extrapolated optimal LR for width={highlight_dim}: {highlight_lr:.4e}")

# Plot
plt.figure(figsize=(8,6))
plt.scatter(model_width, optimal_lr, label='Data', color='blue')
widths_for_line = np.linspace(min(model_width), 512, 200)
plt.plot(widths_for_line, power_law(widths_for_line, *popt), 'r--', label='Power Law Fit')
plt.scatter([highlight_dim], [highlight_lr], color='green', marker='x', label=f'Extrapolated (w={highlight_dim})')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Model Width')
plt.ylabel('Optimal LR')
plt.title('Model Width vs. Optimal LR SGD (Log Scale)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Extrapolated optimal LR for width=32: 1.0000e-01
# Extrapolated optimal LR for width=48: 1.4004e-01
# Extrapolated optimal LR for width=64: 1.7783e-01
# Extrapolated optimal LR for width=80: 2.1403e-01
# Extrapolated optimal LR for width=96: 2.4902e-01
# Extrapolated optimal LR for width=104: 2.6614e-01
# Extrapolated optimal LR for width=128: 3.1623e-01
# Extrapolated optimal LR for width=160: 3.8061e-01
# Extrapolated optimal LR for width=192: 4.4283e-01
# Extrapolated optimal LR for width=224: 5.0331e-01
# Extrapolated optimal LR for width=256: 5.6234e-01
# Fit parameters: A=5.6234e-03, B=0.8305
# Extrapolated optimal LR for width=256: 5.6234e-01
