# %% [markdown]
# ## Scaling Law Ananlysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

experiment_16 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/16d.csv')
experiment_32 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/32d_123.csv')
experiment_24 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/24d_123.csv')
experiment_64 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/64d_123.csv')
experiment_96 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/96d_123.csv')
experiment_128 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/128d.csv')
experiment_16_sgd_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_SGD/16d_123_sgd.csv')
experiment_24_sgd_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_SGD/24d_123_sgd.csv')
experiment_32_sgd_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_SGD/32d_123_sgd.csv')
experiment_48_sgd_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_SGD/48d_123_sgd.csv')
experiment_56_sgd_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_SGD/56d_123_sgd.csv')
experiment_64_sgd_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_SGD/64d_123_sgd.csv')
lstm_16_123 = pd.read_csv('../experimental_data_folder/LSTM_Hidden_Dim_Scaling/LSTM_16d_123.csv')
lstm_24_123 = pd.read_csv('../experimental_data_folder/LSTM_Hidden_Dim_Scaling/LSTM_24d_123.csv')
lstm_32_123 = pd.read_csv('../experimental_data_folder/LSTM_Hidden_Dim_Scaling/LSTM_32d_123.csv')
lstm_48_123 = pd.read_csv('../experimental_data_folder/LSTM_Hidden_Dim_Scaling/LSTM_48d_123.csv')

rmsnorm_32_123 = pd.read_csv('../experimental_data_folder/Norm_Experiments/32d_rmsnorm_123.csv')
postnorm_32_123 = pd.read_csv('../experimental_data_folder/Norm_Experiments/32d_post_layernorm_123.csv')


# 32d_cosine_warmup_32_123 = pd.read_csv('../experimental_data_folder/LR_Schedule_Experiments/32d_123_cosine_warmup.csv')
# inverse_sqrt_32_123 = pd.read_csv('../experimental_data_folder/LR_Schedule_Experiments/32d_123_inverse_sqrt.csv')
# linear_warmup_32_123 = pd.read_csv('../experimental_data_folder/LR_Schedule_Experiments/32d_123_linear_warmup.csv')
# transformer_32_123 = pd.read_csv('../experimental_data_folder/LR_Schedule_Experiments/32d_123_transformer.csv')

# lstm_64_123 = pd.read_csv('../experimental_data_folder/LSTM_Hidden_Dim_Scaling/LSTM_64d_123.csv')

#read the last line of each experiment
last_line_16 = experiment_16.iloc[-1]
last_line_24 = experiment_24.iloc[-1]
last_line_32 = experiment_32.iloc[-1]
last_line_64 = experiment_64.iloc[-1]
last_line_96 = experiment_96.iloc[-1]
last_line_128 = experiment_128.iloc[-1]
last_line_16_sgd_123 = experiment_16_sgd_123.iloc[-1]
last_line_24_sgd_123 = experiment_24_sgd_123.iloc[-1]
last_line_32_sgd_123 = experiment_32_sgd_123.iloc[-1]
last_line_48_sgd_123 = experiment_48_sgd_123.iloc[-1]
last_line_64_sgd_123 = experiment_64_sgd_123.iloc[-1]
last_line_lstm_16_123 = lstm_16_123.iloc[-1]
last_line_lstm_24_123 = lstm_24_123.iloc[-1]
last_line_lstm_32_123 = lstm_32_123.iloc[-1]
last_line_lstm_48_123 = lstm_48_123.iloc[-1]

# ll_cosine_warmup_32_123 = cosine_warmup_32_123.iloc[-1]
# ll_inverse_sqrt_32_123 = inverse_sqrt_32_123.iloc[-1]
# ll_linear_warmup_32_123 = linear_warmup_32_123.iloc[-1]
# ll_transformer_32_123 = transformer_32_123.iloc[-1]
ll_rmsnorm_32_123 = rmsnorm_32_123.iloc[-1]
ll_postnorm_32_123 = postnorm_32_123.iloc[-1]

# last_line_lstm_64_123 = lstm_64_123.iloc[-1]

#print the last line of each experiment
print(last_line_32)
print(last_line_64)
print(last_line_128)


# print(ll_cosine_warmup_32_123)
# print(ll_inverse_sqrt_32_123)
# print(ll_linear_warmup_32_123)
# print(ll_transformer_32_123)
print(ll_rmsnorm_32_123)
print(ll_postnorm_32_123)
# Out:
# step                    7.500000e+02
# training_loss           5.454100e+00
# validation_loss         5.556200e+00
# total_flops_profiler    3.030000e+13
# Name: 269, dtype: float64
# step                    1.650000e+03
# training_loss           4.620300e+00
# validation_loss         4.633300e+00
# total_flops_profiler    1.380000e+14
# Name: 575, dtype: float64
# step                    3.250000e+03
# training_loss           4.466000e+00
# validation_loss         4.237600e+00
# total_flops_profiler    6.400000e+14
# Name: 1119, dtype: float64
# step                    7.500000e+02
# training_loss           5.910900e+00
# validation_loss         5.986000e+00
# total_flops_profiler    3.030000e+13
# Name: 269, dtype: float64
# step                    7.500000e+02
# training_loss           5.858000e+00
# validation_loss         5.933800e+00
# total_flops_profiler    3.030000e+13
# Name: 269, dtype: float64

# %%
final_val_loss_sgd_123 = [last_line_16_sgd_123['validation_loss'], last_line_24_sgd_123['validation_loss'], last_line_32_sgd_123['validation_loss'], last_line_48_sgd_123['validation_loss'], last_line_64_sgd_123['validation_loss']]
final_compute_sgd_123 = [last_line_16_sgd_123['total_flops_profiler'], last_line_24_sgd_123['total_flops_profiler'], last_line_32_sgd_123['total_flops_profiler'], last_line_48_sgd_123['total_flops_profiler'], last_line_64_sgd_123['total_flops_profiler']]

final_val_loss_lstm_123 = [last_line_lstm_16_123['validation_loss'], last_line_lstm_24_123['validation_loss'], last_line_lstm_32_123['validation_loss'], last_line_lstm_48_123['validation_loss']]
final_compute_lstm_123 = [last_line_lstm_16_123['total_flops_profiler'], last_line_lstm_24_123['total_flops_profiler'], last_line_lstm_32_123['total_flops_profiler'], last_line_lstm_48_123['total_flops_profiler']]

print(final_val_loss_sgd_123)
print(final_compute_sgd_123)
# Out:
# [8.3557, 8.2626, 8.2009, 8.1229, 8.0618]
# [6970000000000.0, 16500000000000.0, 30100000000000.0, 73600000000000.0, 138000000000000.0]

# %%
#plot of compute vs validation loss for each experiment and fit a power law

final_val_loss = [last_line_16['validation_loss'], last_line_24['validation_loss'], last_line_32['validation_loss'], last_line_64['validation_loss'], last_line_96['validation_loss'], last_line_128['validation_loss']]
final_compute = [last_line_16['total_flops_profiler'], last_line_24['total_flops_profiler'], last_line_32['total_flops_profiler'], last_line_64['total_flops_profiler'], last_line_96['total_flops_profiler'], last_line_128['total_flops_profiler']]

print(final_val_loss)
final_val_loss_irreducible = [val - 1.76 for val in final_val_loss]

# Fit a power law: y = a * x^b
import numpy as np
from scipy.optimize import curve_fit

def power_law(x, a, b):
    return a * np.power(x, b)

# Convert to numpy arrays
x_data = np.array(final_compute)
y_data = np.array(final_val_loss_irreducible)

# Fit the power law
params, covariance = curve_fit(power_law, x_data, y_data)
a, b = params
print(f"Power law fit: y = {a:.4e} * x^({b:.4f})")

# Generate fitted curve for plotting
x_fit = np.logspace(np.log10(min(x_data)), np.log10(max(x_data)), 100)
y_fit = power_law(x_fit, a, b)

# Plot the data and the fit
plt.scatter(final_compute, final_val_loss_irreducible, label='Data')
plt.plot(x_fit, y_fit, 'r-', label=f'Fit: y = {a:.2e} * x^({b:.4f})')
plt.xlabel('Compute (FLOPS)')
plt.ylabel('Validation Loss (Irreducible)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.title('Power Law Scaling of Loss vs Compute')
plt.show()
# Out:
# [6.8202, 5.8276, 5.5562, 4.6333, 4.3181, 4.2376]
# Power law fit: y = 6.6291e+02 * x^(-0.1660)

# %% [markdown]
# ## Scaling Law With Non-Rotary

# %%
experiment_16_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/16d_no_rotary.csv')
experiment_24_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/24d_no_rotary_123.csv')
experiment_32_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/32d_no_rotary.csv')
experiment_48_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/48d_no_rotary_123.csv')
experiment_64_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/64d_no_rotary.csv')
experiment_96_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/96d_no_rotary.csv')
experiment_128_no_rotary = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary/128d_no_rotary_123.csv')

last_line_16_no_rotary = experiment_16_no_rotary.iloc[-1]
last_line_24_no_rotary = experiment_24_no_rotary.iloc[-1]
last_line_32_no_rotary = experiment_32_no_rotary.iloc[-1]
last_line_48_no_rotary = experiment_48_no_rotary.iloc[-1]
last_line_64_no_rotary = experiment_64_no_rotary.iloc[-1]
last_line_96_no_rotary = experiment_96_no_rotary.iloc[-1]
last_line_128_no_rotary = experiment_128_no_rotary.iloc[-1]

print(last_line_16_no_rotary)
print(last_line_32_no_rotary)
print(last_line_64_no_rotary)
print(last_line_96_no_rotary)
print(last_line_128_no_rotary)


final_val_loss = [last_line_16_no_rotary['validation_loss'], last_line_24_no_rotary['validation_loss'], last_line_32_no_rotary['validation_loss'], last_line_48_no_rotary['validation_loss'], last_line_64_no_rotary['validation_loss'], last_line_96_no_rotary['validation_loss'], last_line_128_no_rotary['validation_loss']]
final_compute = [last_line_16_no_rotary['total_flops_profiler'], last_line_24_no_rotary['total_flops_profiler'], last_line_32_no_rotary['total_flops_profiler'], last_line_48_no_rotary['total_flops_profiler'], last_line_64_no_rotary['total_flops_profiler'], last_line_96_no_rotary['total_flops_profiler'], last_line_128_no_rotary['total_flops_profiler']]


import numpy as np
from scipy.optimize import curve_fit


final_compute = final_compute
final_val_loss_irreducible = final_val_loss
final_val_loss_irreducible = [val - 1.76 for val in final_val_loss_irreducible]

def power_law(x, a, b):
    return a * np.power(x, b)
#fit a power law to the data
x_data = np.array(final_compute)
y_data = np.array(final_val_loss_irreducible)

# Fit the power law
params, covariance = curve_fit(power_law, x_data, y_data)
a, b = params
print(f"Power law fit: y = {a:.4e} * x^({b:.4f})")

# Generate fitted curve for plotting
x_fit = np.logspace(np.log10(min(x_data)), np.log10(max(x_data)), 100)
y_fit = power_law(x_fit, a, b)



plt.scatter(final_compute, final_val_loss_irreducible, label='Data')
plt.plot(x_fit, y_fit, 'r-', label=f'Fit: y = {a:.2e} * x^({b:.4f})')
plt.xlabel('Compute (FLOPS)')
plt.ylabel('Validation Loss (Irreducible)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.title('Power Law Scaling of Loss vs Compute')
plt.show()
# Out:
# step                    3.500000e+02
# training_loss           7.418200e+00
# validation_loss         7.457100e+00
# total_flops_profiler    6.970000e+12
# Name: 133, dtype: float64
# step                    7.500000e+02
# training_loss           6.582400e+00
# validation_loss         6.421300e+00
# total_flops_profiler    3.030000e+13
# Name: 269, dtype: float64
# step                    1.650000e+03
# training_loss           5.206800e+00
# validation_loss         5.163200e+00
# total_flops_profiler    1.380000e+14
# Name: 568, dtype: float64
# step                    2.650000e+03
# training_loss           4.674000e+00
# validation_loss         4.678500e+00
# total_flops_profiler    3.570000e+14
# Name: 915, dtype: float64
# step                    3.250000e+03
# training_loss           4.620300e+00
# validation_loss         4.738500e+00
# total_flops_profiler    6.390000e+14
# Name: 1119, dtype: float64
# Power law fit: y = 8.0558e+02 * x^(-0.1657)

# %% [markdown]
# ## Compute Multiplier Over Scale

# %%
def compute_multiplier(loss_1, loss_2, irreducible = 1.76):
    compute_effect = 0.154
    diff = np.log(loss_1-irreducible)-np.log(loss_2-irreducible)
    return np.exp(diff/compute_effect)


final_compute = [last_line_16_no_rotary['total_flops_profiler'], last_line_24_no_rotary['total_flops_profiler'], last_line_32_no_rotary['total_flops_profiler'], last_line_64_no_rotary['total_flops_profiler'], last_line_96_no_rotary['total_flops_profiler'], last_line_128_no_rotary['total_flops_profiler']]




compute_multiplier_16 = compute_multiplier(last_line_16_no_rotary['validation_loss'],last_line_16['validation_loss'])
compute_multiplier_24 = compute_multiplier(last_line_24_no_rotary['validation_loss'],last_line_24['validation_loss'])
compute_multiplier_32 = compute_multiplier(last_line_32_no_rotary['validation_loss'],last_line_32['validation_loss'])
compute_multiplier_64 = compute_multiplier(last_line_64_no_rotary['validation_loss'],last_line_64['validation_loss'])
compute_multiplier_96 = compute_multiplier(last_line_96_no_rotary['validation_loss'],last_line_96['validation_loss'])
compute_multiplier_128 = compute_multiplier(last_line_128_no_rotary['validation_loss'],last_line_128['validation_loss'])


print(compute_multiplier_16, compute_multiplier_24, compute_multiplier_32, compute_multiplier_64, compute_multiplier_96, compute_multiplier_128)
#graph compute multiplier vs compute used
compute_multipliers = [compute_multiplier_16, compute_multiplier_24, compute_multiplier_32, compute_multiplier_64, compute_multiplier_96, compute_multiplier_128]

plt.scatter(final_compute, compute_multipliers)
plt.xlabel('Compute Used')
plt.ylabel('Compute Multiplier')
plt.yscale('log')
plt.show()
# Out:
# 2.1593633018895386 8.831599329301147 3.7926944623680177 3.0013381814211333 2.353436404726452 3.3056922236305573

# %% [markdown]
# ## Second Seed Experiments

# %%
import pandas as pd
import matplotlib.pyplot as plt

experiment_16_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/16d_123.csv')
experiment_24_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/24d_123.csv')
experiment_32_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/32d_123.csv')
experiment_64_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/64d_123.csv')
experiment_96_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling/96d_123.csv')


#read the last line of each experiment
last_line_16_123 = experiment_16_123.iloc[-1]
last_line_24_123 = experiment_24_123.iloc[-1]
last_line_32_123 = experiment_32_123.iloc[-1]
last_line_64_123 = experiment_64_123.iloc[-1]
last_line_96_123 = experiment_96_123.iloc[-1]

# %%
#plot of compute vs validation loss for each experiment and fit a power law

final_val_loss = [last_line_16_123['validation_loss'], last_line_24_123['validation_loss'], last_line_32_123['validation_loss'], last_line_64_123['validation_loss'], last_line_96_123['validation_loss']]
final_compute = [last_line_16_123['total_flops_profiler'], last_line_24_123['total_flops_profiler'], last_line_32_123['total_flops_profiler'], last_line_64_123['total_flops_profiler'], last_line_96_123['total_flops_profiler']]

print(final_val_loss)
final_val_loss_irreducible_standard_123 = [val - 1.76 for val in final_val_loss]

# Fit a power law: y = a * x^b
import numpy as np
from scipy.optimize import curve_fit

def power_law(x, a, b):
    return a * np.power(x, b)

# Convert to numpy arrays
x_data_standard_123 = np.array(final_compute)

y_data_standard_123 = np.array(final_val_loss_irreducible_standard_123)

# Fit the power law
params, covariance = curve_fit(power_law, x_data_standard_123, y_data_standard_123)
a, b = params
print(f"Power law fit: y = {a:.4e} * x^({b:.4f})")

# Generate fitted curve for plotting
x_fit_standard_123 = np.logspace(np.log10(min(x_data_standard_123)), np.log10(max(x_data_standard_123)), 100)
y_fit_standard_123 = power_law(x_fit_standard_123, a, b)

# Plot the data and the fit
plt.scatter(final_compute, final_val_loss_irreducible_standard_123, label='Data')
plt.plot(x_fit_standard_123, y_fit_standard_123, 'r-', label=f'Fit: y = {a:.2e} * x^({b:.4f})')
plt.xlabel('Compute (FLOPS)')
plt.ylabel('Validation Loss (Irreducible)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.title('Power Law Scaling of Loss vs Compute Stanard')
plt.show()
# Out:
# [6.8265, 5.8276, 5.5562, 4.6333, 4.3181]
# Power law fit: y = 9.4426e+02 * x^(-0.1776)

# %%
experiment_16_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/16d_no_rotary_123.csv')
experiment_32_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/32d_no_rotary_123.csv')
experiment_24_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/24d_no_rotary_123.csv')
experiment_64_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/64d_no_rotary_123.csv')
experiment_96_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/96d_no_rotary_123.csv')

last_line_16_no_rotary_123 = experiment_16_no_rotary_123.iloc[-1]
last_line_24_no_rotary_123 = experiment_24_no_rotary_123.iloc[-1]
last_line_32_no_rotary_123 = experiment_32_no_rotary_123.iloc[-1]
last_line_64_no_rotary_123 = experiment_64_no_rotary_123.iloc[-1]
last_line_96_no_rotary_123 = experiment_96_no_rotary_123.iloc[-1]

print(last_line_16_no_rotary_123)
print(last_line_32_no_rotary_123)
print(last_line_64_no_rotary_123)
print(last_line_96_no_rotary_123)

final_val_loss_no_rotary_123 = [
    last_line_16_no_rotary_123['validation_loss'],
    last_line_24_no_rotary_123['validation_loss'],
    last_line_32_no_rotary_123['validation_loss'],
    last_line_64_no_rotary_123['validation_loss'],
    last_line_96_no_rotary_123['validation_loss']
]

final_compute = [
    last_line_16_no_rotary_123['total_flops_profiler'],
    last_line_24_no_rotary_123['total_flops_profiler'],
    last_line_32_no_rotary_123['total_flops_profiler'],
    last_line_64_no_rotary_123['total_flops_profiler'],
    last_line_96_no_rotary_123['total_flops_profiler']
]

import numpy as np
from scipy.optimize import curve_fit

final_val_loss_irreducible_no_rotary = [val - 1.76 for val in final_val_loss_no_rotary_123]

def power_law(x, a, b):
    return a * np.power(x, b)

# Fit a power law to the no-rotary data and get error estimates
x_data = np.array(final_compute)
y_data = np.array(final_val_loss_irreducible_no_rotary)
params, covariance = curve_fit(power_law, x_data, y_data)
a_no_rotary, b_no_rotary = params
perr_no_rotary = np.sqrt(np.diag(covariance))
a_no_rotary_err, b_no_rotary_err = perr_no_rotary
print(f"Power law fit (no rotary): y = {a_no_rotary:.4e} * x^({b_no_rotary:.4f})")
print(f"Exponent (no rotary) error estimate: {b_no_rotary:.4f} ± {b_no_rotary_err:.4f}")

# Generate fitted curve for plotting
x_fit_no_rotary_123 = np.logspace(np.log10(min(x_data)), np.log10(max(x_data)), 100)
y_fit_no_rotary_123 = power_law(x_fit_no_rotary_123, a_no_rotary, b_no_rotary)

# SGD
final_val_loss_irreducible_sgd_123 = [val - 1.76 for val in final_val_loss_sgd_123]
x_data_sgd_123 = np.array(final_compute_sgd_123)
y_data_sgd_123 = np.array(final_val_loss_irreducible_sgd_123)
params, covariance = curve_fit(power_law, x_data_sgd_123, y_data_sgd_123)
a_sgd_123, b_sgd_123 = params
perr_sgd_123 = np.sqrt(np.diag(covariance))
a_sgd_123_err, b_sgd_123_err = perr_sgd_123
print(f"Power law fit (sgd): y = {a_sgd_123:.4e} * x^({b_sgd_123:.4f})")
print(f"Exponent (sgd) error estimate: {b_sgd_123:.4f} ± {b_sgd_123_err:.4f}")

x_fit_sgd_123 = np.logspace(np.log10(min(x_data_sgd_123)), np.log10(max(x_data_sgd_123)), 100)
y_fit_sgd_123 = power_law(x_fit_sgd_123, a_sgd_123, b_sgd_123)
plt.plot(x_fit_sgd_123, y_fit_sgd_123, 'b-', label=f'Fit: y = {a_sgd_123:.2e} * x^({b_sgd_123:.4f})')
plt.scatter(final_compute_sgd_123, final_val_loss_irreducible_sgd_123, label='sgd')

# LSTM
final_val_loss_irreducible_lstm_123 = [val - 1.76 for val in final_val_loss_lstm_123]
x_data_lstm_123 = np.array(final_compute_lstm_123)
y_data_lstm_123 = np.array(final_val_loss_irreducible_lstm_123)
params, covariance = curve_fit(power_law, x_data_lstm_123, y_data_lstm_123)
a_lstm_123, b_lstm_123 = params
perr_lstm_123 = np.sqrt(np.diag(covariance))
a_lstm_123_err, b_lstm_123_err = perr_lstm_123
print(f"Power law fit (lstm): y = {a_lstm_123:.4e} * x^({b_lstm_123:.4f})")
print(f"Exponent (lstm) error estimate: {b_lstm_123:.4f} ± {b_lstm_123_err:.4f}")

x_fit_lstm_123 = np.logspace(np.log10(min(x_data_lstm_123)), np.log10(max(x_data_lstm_123)), 100)
y_fit_lstm_123 = power_law(x_fit_lstm_123, a_lstm_123, b_lstm_123)
plt.scatter(final_compute_lstm_123, final_val_loss_irreducible_lstm_123, label='lstm')
plt.plot(x_fit_lstm_123, y_fit_lstm_123, 'g-', label=f'Fit: y = {a_lstm_123:.2e} * x^({b_lstm_123:.4f})')

print(x_fit_no_rotary_123)
print(y_fit_no_rotary_123)
plt.plot(x_fit_no_rotary_123, y_fit_no_rotary_123, 'r-', label=f'Fit: y = {a_no_rotary:.2e} * x^({b_no_rotary:.4f})')

plt.scatter(final_compute, final_val_loss_irreducible_no_rotary, label='no rotary')
plt.scatter(final_compute, final_val_loss_irreducible_standard_123, label='standard')
plt.plot(x_fit_standard_123, y_fit_standard_123, 'r-', label=f'Fit: y = {a:.2e} * x^({b:.4f}) stuff')
plt.xlabel('Compute (FLOPS)')
plt.ylabel('Validation Loss (Irreducible)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.7))
plt.title('Power Law Scaling of Loss vs Compute Non Rotary 123')
plt.savefig('Figures/universal_scaling_law_study.png')
plt.show()
# Out:
# step                    3.500000e+02
# training_loss           7.422900e+00
# validation_loss         7.453900e+00
# total_flops_profiler    6.970000e+12
# Name: 133, dtype: float64
# step                    7.500000e+02
# training_loss           6.202400e+00
# validation_loss         6.273600e+00
# total_flops_profiler    3.030000e+13
# Name: 269, dtype: float64
# step                    1.650000e+03
# training_loss           5.130300e+00
# validation_loss         5.104000e+00
# total_flops_profiler    1.380000e+14
# Name: 575, dtype: float64
# step                    2.650000e+03
# training_loss           4.451600e+00
# validation_loss         4.619600e+00
# total_flops_profiler    3.570000e+14
# Name: 915, dtype: float64
# Power law fit (no rotary): y = 1.1442e+03 * x^(-0.1786)
# Exponent (no rotary) error estimate: -0.1786 ± 0.0114
# Power law fit (sgd): y = 1.0310e+01 * x^(-0.0151)
# Exponent (sgd) error estimate: -0.0151 ± 0.0003
# Power law fit (lstm): y = 1.0655e+02 * x^(-0.0928)
# Exponent (lstm) error estimate: -0.0928 ± 0.0055
# [6.97000000e+12 7.25270149e+12 7.54686928e+12 7.85296844e+12
#  8.17148291e+12 8.50291624e+12 8.84779244e+12 9.20665672e+12
#  9.58007646e+12 9.96864200e+12 1.03729677e+13 1.07936927e+13
#  1.12314822e+13 1.16870284e+13 1.21610514e+13 1.26543006e+13
#  1.31675559e+13 1.37016288e+13 1.42573635e+13 1.48356386e+13
#  1.54373685e+13 1.60635044e+13 1.67150361e+13 1.73929939e+13
#  1.80984495e+13 1.88325181e+13 1.95963604e+13 2.03911840e+13
#  2.12182454e+13 2.20788522e+13 2.29743650e+13 2.39061996e+13
#  2.48758292e+13 2.58847867e+13 2.69346673e+13 2.80271308e+13
#  2.91639043e+13 3.03467851e+13 3.15776432e+13 3.28584247e+13
#  3.41911543e+13 3.55779391e+13 3.70209716e+13 3.85225331e+13
#  4.00849976e+13 4.17108352e+13 4.34026164e+13 4.51630159e+13
#  4.69948167e+13 4.89009149e+13 5.08843240e+13 5.29481797e+13
#  5.50957448e+13 5.73304147e+13 5.96557222e+13 6.20753437e+13
#  6.45931043e+13 6.72129848e+13 6.99391269e+13 7.27758407e+13
#  7.57276109e+13 7.87991042e+13 8.19951765e+13 8.53208807e+13
#  8.87814746e+13 9.23824294e+13 9.61294380e+13 1.00028424e+14
#  1.04085553e+14 1.08307237e+14 1.12700152e+14 1.17271243e+14
#  1.22027735e+14 1.26977150e+14 1.32127312e+14 1.37486364e+14
#  1.43062777e+14 1.48865368e+14 1.54903310e+14 1.61186151e+14
#  1.67723821e+14 1.74526658e+14 1.81605416e+14 1.88971288e+14
#  1.96635916e+14 2.04611421e+14 2.12910410e+14 2.21546004e+14
#  2.30531855e+14 2.39882171e+14 2.49611732e+14 2.59735923e+14
#  2.70270748e+14 2.81232863e+14 2.92639599e+14 3.04508989e+14
#  3.16859799e+14 3.29711554e+14 3.43084574e+14 3.57000000e+14]
# [5.82433472 5.78313266 5.74222207 5.70160088 5.66126706 5.62121856
#  5.58145337 5.54196948 5.50276491 5.46383767 5.42518581 5.38680738
#  5.34870044 5.31086308 5.27329338 5.23598945 5.19894942 5.16217141
#  5.12565358 5.08939407 5.05339107 5.01764276 4.98214734 4.94690302
#  4.91190802 4.87716057 4.84265894 4.80840138 4.77438615 4.74061156
#  4.70707589 4.67377746 4.64071458 4.60788559 4.57528884 4.54292269
#  4.51078549 4.47887564 4.44719153 4.41573155 4.38449412 4.35347767
#  4.32268063 4.29210146 4.2617386  4.23159054 4.20165575 4.17193272
#  4.14241995 4.11311596 4.08401928 4.05512842 4.02644194 3.9979584
#  3.96967635 3.94159437 3.91371105 3.88602497 3.85853475 3.83123901
#  3.80413635 3.77722542 3.75050486 3.72397333 3.69762949 3.671472
#  3.64549956 3.61971084 3.59410456 3.56867943 3.54343415 3.51836746
#  3.4934781  3.4687648  3.44422633 3.41986145 3.39566893 3.37164755
#  3.3477961  3.32411338 3.30059819 3.27724936 3.25406569 3.23104603
#  3.20818921 3.18549409 3.16295951 3.14058435 3.11836747 3.09630775
#  3.07440409 3.05265538 3.03106052 3.00961842 2.98832801 2.96718821
#  2.94619796 2.92535619 2.90466186 2.88411393]

# %% [markdown]
# # With All Training Points

# %%
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# Read CSVs for all runs
experiment_16_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/16d_no_rotary_123.csv')
experiment_24_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/24d_no_rotary_123.csv')
experiment_32_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/32d_no_rotary_123.csv')
experiment_64_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/64d_no_rotary_123.csv')
experiment_96_no_rotary_123 = pd.read_csv('../experimental_data_folder/Hidden_Dim_Scaling_No_Rotary_123/96d_no_rotary_123.csv')

irreducible = 1.76

# Get last lines for summary points
last_line_16_no_rotary_123 = experiment_16_no_rotary_123.iloc[-1]
last_line_24_no_rotary_123 = experiment_24_no_rotary_123.iloc[-1]
last_line_32_no_rotary_123 = experiment_32_no_rotary_123.iloc[-1]
last_line_64_no_rotary_123 = experiment_64_no_rotary_123.iloc[-1]
last_line_96_no_rotary_123 = experiment_96_no_rotary_123.iloc[-1]

print(last_line_16_no_rotary_123)
print(last_line_32_no_rotary_123)
print(last_line_64_no_rotary_123)
print(last_line_96_no_rotary_123)

final_val_loss_no_rotary_123 = [
    last_line_16_no_rotary_123['validation_loss'],
    last_line_24_no_rotary_123['validation_loss'],
    last_line_32_no_rotary_123['validation_loss'],
    last_line_64_no_rotary_123['validation_loss'],
    last_line_96_no_rotary_123['validation_loss']
]

final_compute = [
    last_line_16_no_rotary_123['total_flops_profiler'],
    last_line_24_no_rotary_123['total_flops_profiler'],
    last_line_32_no_rotary_123['total_flops_profiler'],
    last_line_64_no_rotary_123['total_flops_profiler'],
    last_line_96_no_rotary_123['total_flops_profiler']
]

# Subtract irreducible from final losses
final_val_loss_irreducible_no_rotary = [val - irreducible for val in final_val_loss_no_rotary_123]

def power_law(x, a, b):
    return a * np.power(x, b)

# Fit a power law to the summary points
x_data = np.array(final_compute)
y_data = np.array(final_val_loss_irreducible_no_rotary)
params, covariance = curve_fit(power_law, x_data, y_data)
a_no_rotary, b_no_rotary = params
print(f"Power law fit: y = {a_no_rotary:.4e} * x^({b_no_rotary:.4f})")

# Generate fitted curve for plotting
x_fit_no_rotary_123 = np.logspace(np.log10(min(x_data)), np.log10(max(x_data)), 100)
y_fit_no_rotary_123 = power_law(x_fit_no_rotary_123, a_no_rotary, b_no_rotary)

# --- Plot all intermediate points for each run ---
color_map = {
    16: 'tab:orange',
    24: 'tab:purple',
    32: 'tab:green',
    64: 'tab:blue',
    96: 'tab:red'
}
label_map = {
    16: '16d no rotary',
    24: '24d no rotary',
    32: '32d no rotary',
    64: '64d no rotary',
    96: '96d no rotary'
}
experiments = [
    (16, experiment_16_no_rotary_123),
    (24, experiment_24_no_rotary_123),
    (32, experiment_32_no_rotary_123),
    (64, experiment_64_no_rotary_123),
    (96, experiment_96_no_rotary_123)
]

for dim, df in experiments:
    compute_vals = df['total_flops_profiler'].values
    loss_vals = df['validation_loss'].values - irreducible
    # Only plot points with positive loss after subtraction
    mask = loss_vals > 0
    plt.plot(compute_vals[mask], loss_vals[mask], 
             marker='o', linestyle='-', 
             color=color_map[dim], 
             alpha=0.5, 
             label=f'{label_map[dim]} (all steps)')

# Plot summary points (final points) as large dots with high zorder for emphasis
plt.scatter(final_compute, final_val_loss_irreducible_no_rotary, 
            color='black', s=250, marker='*', label='no rotary (final)', zorder=100)

# --- The rest of the original plotting code for other curves ---

# now stuff without sgd
final_val_loss_irreducible_sgd_123 = [val - irreducible for val in final_val_loss_sgd_123]
x_data_sgd_123 = np.array(final_compute_sgd_123)
y_data_sgd_123 = np.array(final_val_loss_irreducible_sgd_123)
params, covariance = curve_fit(power_law, x_data_sgd_123, y_data_sgd_123)
a_sgd_123, b_sgd_123 = params
print(f"Power law fit: y = {a_sgd_123:.4e} * x^({b_sgd_123:.4f})")
x_fit_sgd_123 = np.logspace(np.log10(min(x_data_sgd_123)), np.log10(max(x_data_sgd_123)), 100)
y_fit_sgd_123 = power_law(x_fit_sgd_123, a_sgd_123, b_sgd_123)
plt.plot(x_fit_sgd_123, y_fit_sgd_123, 'b-', label=f'Fit: y = {a_sgd_123:.2e} * x^({b_sgd_123:.4f})')
# Emphasize final SGD points
plt.scatter(final_compute_sgd_123, final_val_loss_irreducible_sgd_123, s=200, color='blue', marker='*', label='sgd (final)', zorder=99)

# lstm stuff 
final_val_loss_irreducible_lstm_123 = [val - irreducible for val in final_val_loss_lstm_123]
x_data_lstm_123 = np.array(final_compute_lstm_123)
y_data_lstm_123 = np.array(final_val_loss_irreducible_lstm_123)
params, covariance = curve_fit(power_law, x_data_lstm_123, y_data_lstm_123)
a_lstm_123, b_lstm_123 = params
print(f"Power law fit: y = {a_lstm_123:.4e} * x^({b_lstm_123:.4f})")
x_fit_lstm_123 = np.logspace(np.log10(min(x_data_lstm_123)), np.log10(max(x_data_lstm_123)), 100)
y_fit_lstm_123 = power_law(x_fit_lstm_123, a_lstm_123, b_lstm_123)
plt.scatter(final_compute_lstm_123, final_val_loss_irreducible_lstm_123, s=200, color='green', marker='^', label='lstm (final)', zorder=98)
plt.plot(x_fit_lstm_123, y_fit_lstm_123, 'g-', label=f'Fit: y = {a_lstm_123:.2e} * x^({b_lstm_123:.4f})')

# Plot the no rotary fit curve
plt.plot(x_fit_no_rotary_123, y_fit_no_rotary_123, 'r-', label=f'Fit: y = {a_no_rotary:.2e} * x^({b_no_rotary:.4f})')

# Plot standard and other summary points
plt.scatter(final_compute, final_val_loss_irreducible_no_rotary, label='no rotary', s=80, color='black', marker='*', zorder=100)
plt.scatter(final_compute, final_val_loss_irreducible_standard_123, label='standard', s=120, color='magenta', marker='P', zorder=97)
plt.plot(x_fit_standard_123, y_fit_standard_123, 'r-', label=f'Fit: y = {a:.2e} * x^({b:.4f}) stuff')

# --- Add SGD intermediate points ---
sgd_color_map = {
    16: 'tab:cyan',
    24: 'tab:pink', 
    32: 'tab:brown',
    48: 'tab:gray',
    64: 'tab:olive'
}
sgd_label_map = {
    16: '16d SGD',
    24: '24d SGD', 
    32: '32d SGD',
    48: '48d SGD',
    64: '64d SGD'
}
sgd_experiments = [
    (16, experiment_16_sgd_123),
    (24, experiment_24_sgd_123),
    (32, experiment_32_sgd_123),
    (48, experiment_48_sgd_123),
    (64, experiment_64_sgd_123)
]

for dim, df in sgd_experiments:
    compute_vals = df['total_flops_profiler'].values
    loss_vals = df['validation_loss'].values - irreducible
    # Only plot points with positive loss after subtraction
    mask = loss_vals > 0
    plt.plot(compute_vals[mask], loss_vals[mask], 
             marker='s', linestyle='--',  # Different marker and line style for SGD
             color=sgd_color_map[dim], 
             alpha=0.6, 
             label=f'{sgd_label_map[dim]} (all steps)')

# --- Add LSTM intermediate points ---
lstm_color_map = {
    16: 'tab:red',
    24: 'tab:orange',
    32: 'tab:purple',
    48: 'tab:green'
}
lstm_label_map = {
    16: '16d LSTM',
    24: '24d LSTM',
    32: '32d LSTM', 
    48: '48d LSTM'
}
lstm_experiments = [
    (16, lstm_16_123),
    (24, lstm_24_123),
    (32, lstm_32_123),
    (48, lstm_48_123)
]

for dim, df in lstm_experiments:
    compute_vals = df['total_flops_profiler'].values
    loss_vals = df['validation_loss'].values - irreducible
    # Only plot points with positive loss after subtraction
    mask = loss_vals > 0
    plt.plot(compute_vals[mask], loss_vals[mask], 
             marker='^', linestyle=':',  # Different marker and line style for LSTM
             color=lstm_color_map[dim], 
             alpha=0.7, 
             label=f'{lstm_label_map[dim]} (all steps)')

# Plot LSTM summary points (final points) as large triangles with high zorder
plt.scatter(final_compute_lstm_123, final_val_loss_irreducible_lstm_123, 
            color='green', s=200, marker='^', label='LSTM (final)', zorder=98)

plt.xlabel('Compute (FLOPS)')
plt.ylabel('Validation Loss (Irreducible)')
plt.yscale('log')
plt.xscale('log')
# plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.7))
plt.title('Power Law Scaling of Loss vs Compute Non Rotary 123')
plt.savefig('Figures/universal_scaling_law_study.png')
plt.show()
# Out:
# step                    3.500000e+02
# training_loss           7.422900e+00
# validation_loss         7.453900e+00
# total_flops_profiler    6.970000e+12
# Name: 133, dtype: float64
# step                    7.500000e+02
# training_loss           6.202400e+00
# validation_loss         6.273600e+00
# total_flops_profiler    3.030000e+13
# Name: 269, dtype: float64
# step                    1.650000e+03
# training_loss           5.130300e+00
# validation_loss         5.104000e+00
# total_flops_profiler    1.380000e+14
# Name: 575, dtype: float64
# step                    2.650000e+03
# training_loss           4.451600e+00
# validation_loss         4.619600e+00
# total_flops_profiler    3.570000e+14
# Name: 915, dtype: float64
# Power law fit: y = 1.1442e+03 * x^(-0.1786)
# Power law fit: y = 1.0310e+01 * x^(-0.0151)
# Power law fit: y = 1.0655e+02 * x^(-0.0928)

# %%
plt.plot(x_fit_no_rotary_123, y_fit_no_rotary_123, 'r-', label=f'Fit: y = {a_no_rotary:.2e} * x^({b_no_rotary:.4f})')

# %%
def compute_multiplier(loss_1, loss_2, irreducible = 1.76):
    compute_effect = 0.154
    diff = np.log(loss_1-irreducible)-np.log(loss_2-irreducible)
    return np.exp(diff/compute_effect)



compute_multiplier_16_123 = compute_multiplier(last_line_16_no_rotary_123['validation_loss'],last_line_16_123['validation_loss'])
compute_multiplier_24_123 = compute_multiplier(last_line_24_no_rotary_123['validation_loss'],last_line_24_123['validation_loss'])
compute_multiplier_32_123 = compute_multiplier(last_line_32_no_rotary_123['validation_loss'],last_line_32_123['validation_loss'])
compute_multiplier_64_123 = compute_multiplier(last_line_64_no_rotary_123['validation_loss'],last_line_64_123['validation_loss'])
compute_multiplier_96_123 = compute_multiplier(last_line_96_no_rotary_123['validation_loss'],last_line_96_123['validation_loss'])


print(compute_multiplier_16_123, compute_multiplier_24_123, compute_multiplier_32_123, compute_multiplier_64_123, compute_multiplier_96_123)
#graph compute multiplier vs compute used
compute_multipliers_123 = [compute_multiplier_16_123, compute_multiplier_24_123, compute_multiplier_32_123, compute_multiplier_64_123, compute_multiplier_96_123]

plt.scatter(final_compute, compute_multipliers_123)
plt.xlabel('Compute Used')
plt.ylabel('Compute Multiplier')
plt.show()
# Out:
# 2.13418662099451 4.776328680230625 3.0771080971183773 2.678098811865548 2.06160900816423
